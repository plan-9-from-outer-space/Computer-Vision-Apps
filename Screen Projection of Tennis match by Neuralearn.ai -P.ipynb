# %%
! pip install deep-sort-realtime
! pip install ultralytics
# Out:
# Collecting deep-sort-realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deep-sort-realtime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from deep-sort-realtime) (1.16.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from deep-sort-realtime) (4.12.0.88)
# Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 80.1 MB/s eta 0:00:00
# Installing collected packages: deep-sort-realtime
# Successfully installed deep-sort-realtime-1.3.2
# Collecting ultralytics
#   Downloading ultralytics-8.4.2-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.2 ultralytics-thop-2.0.18

# %%
import requests
import cv2
import torch
from ultralytics import YOLO
from PIL import Image
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection
import datetime
from deep_sort_realtime.deepsort_tracker import DeepSort # for tracking
import matplotlib.pyplot as plt
from PIL import ImageDraw
import numpy as np
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Link to Best weights: https://drive.google.com/file/d/1nI8n3Q6yn7c_X6a_iB15ZlUvqq-aWyd_/view?usp=drive_link

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Use a zero shot model for tennis player detection
model_id = "IDEA-Research/grounding-dino-tiny"
device = "cuda"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)
# Out:
# preprocessor_config.json:   0%|          | 0.00/457 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/689M [00:00<?, ?B/s]

# %%
# Use the customer trained model for tennis ball detection
weights = "best_instructor" # "best_bob"
yolo_model = YOLO (f"/content/drive/MyDrive/datasetyolo/weights/{weights}.pt")

# %%
def ball_detections (image):
  results = yolo_model (image, conf=0.01)
  results_for_image = results[0]
  num_detections = len(results_for_image.boxes)
  bbox = None
  if num_detections > 0:
    for i, detection in enumerate(results_for_image.boxes):
      bbox = detection.xyxy[0].cpu().numpy()
      break
  return bbox

# %%
def player_detections (frame):
  image = Image.fromarray(frame)

  text_labels = ["person"] # ["tennis player"]
  inputs = processor(
    images = image.convert("RGB"),
    text = text_labels,
    return_tensors = "pt").to(device)
  with torch.no_grad():
    outputs = model (**inputs)

  results = processor.post_process_grounded_object_detection (
    outputs,
    inputs.input_ids,
    text_threshold = 0.3,
    target_sizes = [image.size[::-1]]
  )

  result = results[0]
  preds = []
  for box, score, labels in zip(result["boxes"], result["scores"], result["labels"]):
    if labels in text_labels:
      box = [int(x) for x in box.tolist()]
      preds.append([[box[0], box[1], box[2] - box[0], box[3] - box[1]], score.item(), 1])

  return preds

# %%
confidence = 0.01
weights = "best_instructor" # "best_bob"

yolo_model = YOLO (f"/content/drive/MyDrive/datasetyolo/weights/{weights}.pt")
input_video_path  = f"/content/drive/MyDrive/tennis-videos/tennis_video.mp4"
output_video_path = f"/content/drive/MyDrive/tennis-videos/output_video_s7_{weights}.mp4"

video_cap = cv2.VideoCapture (input_video_path)

tracker = DeepSort (max_age=100)

frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(video_cap.get(cv2.CAP_PROP_FPS))
print(f"total_frames = {total_frames}")
print(f"fps = {fps}")
print(f"frame width = {frame_width}")
print(f"frame height = {frame_height}")

fourcc = cv2.VideoWriter_fourcc (*'mp4v')
# fps = 1  # Slow the output video down for easier analysis
writer = cv2.VideoWriter (output_video_path, fourcc, fps, (frame_width, frame_height))
# Out:
# total_frames = 214
# fps = 30
# frame width = 1920
# frame height = 1080

# %%
tracking = []

while video_cap.isOpened():

    start = datetime.datetime.now()
    ret, frame = video_cap.read()
    if not ret: break

    player_bbox = player_detections (frame)
    tracks = tracker.update_tracks(player_bbox, frame=frame)

    # used to determine which persons moved the most during the match (the two players)
    # this enables the removal of the persons who are not moving very much (line judge, etc)
    frame_tracking = []

    if len(player_bbox) > 0:

      for track in tracks:
        if not track.is_confirmed(): continue

        track_id = track.track_id
        ltrb = track.to_ltrb() # bbox coords
        xmin, ymin, xmax, ymax = int(ltrb[0]), int(ltrb[1]), int(ltrb[2]), int(ltrb[3])
        width = xmax - xmin
        frame_tracking.append([xmin + int(width / 2), ymax, track_id])

        # Player bboxes and labels
        cv2.rectangle (frame, (xmin, ymin), (xmax, ymax), (10, 255, 0), 2)
        cv2.putText (frame, "player_" + str(track_id), (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
        # Extra annotation
        cv2.putText (frame, f"MODEL WEIGHTS: {weights}", (300, 300), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
        cv2.putText (frame, f"CONFIDENCE LEVEL: {confidence}", (300, 325), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
        cv2.putText (frame, f"PLAYERS FOUND: {len(player_bbox)}", (300, 350), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)

      writer.write(frame)
      end = datetime.datetime.now()
      print(f"Time to process 1 frame: {(end - start).total_seconds() * 1000:.0f} milliseconds")

    tracking.append(frame_tracking)

video_cap.release()
writer.release()
# cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/models/grounding_dino/processing_grounding_dino.py:93: FutureWarning: The key `labels` is will return integer ids in `GroundingDinoProcessor.post_process_grounded_object_detection` output since v4.51.0. Use `text_labels` instead to retrieve string object names.
#   warnings.warn(self.message, FutureWarning)
# Time to process 1 frame: 6668 milliseconds
# Time to process 1 frame: 733 milliseconds
# Time to process 1 frame: 3287 milliseconds
# Time to process 1 frame: 3317 milliseconds
# Time to process 1 frame: 4629 milliseconds
# Time to process 1 frame: 718 milliseconds
# Time to process 1 frame: 642 milliseconds
# Time to process 1 frame: 656 milliseconds
# Time to process 1 frame: 649 milliseconds
# Time to process 1 frame: 644 milliseconds
# Time to process 1 frame: 646 milliseconds
# Time to process 1 frame: 663 milliseconds
# Time to process 1 frame: 651 milliseconds
# Time to process 1 frame: 652 milliseconds
# Time to process 1 frame: 648 milliseconds
# Time to process 1 frame: 661 milliseconds
# Time to process 1 frame: 655 milliseconds
# Time to process 1 frame: 654 milliseconds
# Time to process 1 frame: 688 milliseconds
# Time to process 1 frame: 718 milliseconds
# Time to process 1 frame: 755 milliseconds
# Time to process 1 frame: 837 milliseconds
# Time to process 1 frame: 3635 milliseconds
# Time to process 1 frame: 762 milliseconds
# Time to process 1 frame: 718 milliseconds
# Time to process 1 frame: 694 milliseconds
# Time to process 1 frame: 696 milliseconds
# Time to process 1 frame: 704 milliseconds
# Time to process 1 frame: 693 milliseconds
# Time to process 1 frame: 702 milliseconds
# Time to process 1 frame: 714 milliseconds
# Time to process 1 frame: 710 milliseconds
# Time to process 1 frame: 705 milliseconds
# Time to process 1 frame: 793 milliseconds
# Time to process 1 frame: 808 milliseconds
# Time to process 1 frame: 816 milliseconds
# Time to process 1 frame: 819 milliseconds
# Time to process 1 frame: 825 milliseconds
# Time to process 1 frame: 832 milliseconds
# Time to process 1 frame: 868 milliseconds
# Time to process 1 frame: 839 milliseconds
# Time to process 1 frame: 3597 milliseconds
# Time to process 1 frame: 1540 milliseconds
# Time to process 1 frame: 1031 milliseconds
# Time to process 1 frame: 975 milliseconds
# Time to process 1 frame: 819 milliseconds
# Time to process 1 frame: 868 milliseconds
# Time to process 1 frame: 872 milliseconds
# Time to process 1 frame: 855 milliseconds
# Time to process 1 frame: 816 milliseconds
# Time to process 1 frame: 781 milliseconds
# Time to process 1 frame: 799 milliseconds
# Time to process 1 frame: 842 milliseconds
# Time to process 1 frame: 790 milliseconds
# Time to process 1 frame: 825 milliseconds
# Time to process 1 frame: 814 milliseconds
# Time to process 1 frame: 832 milliseconds

# %%
# tracking

# %% [markdown]
# # Filter out the non-player detections

# %%
def euclid_dist (p1, p2):
  # return np.sqrt((pos1[0] - pos2[0])**2 + (pos1[1] - pos2[1])**2)
  return np.linalg.norm(p1 - p2)

# %%
player_ids = []
player_pos = {}
player_dist = {}

for frame in tracking:
  for player in frame:
    player_id = int(player[2])
    if player_id not in player_ids:
      player_pos[player_id] = np.array([player[0], player[1]])
      player_dist[player_id] = 0
      player_ids.append(player_id)
    else:
      player_dist[player_id] = euclid_dist(player_pos[player_id], np.array([player[0], player[1]])) + player_dist[player_id]
      player_pos[player_id] = np.array([player[0], player[1]])

print(player_dist)
# Out:
# {1: np.float64(1540.472657794045), 2: np.float64(1018.820560213182), 3: np.float64(7.0), 4: np.float64(17.0), 5: np.float64(39.0), 6: np.float64(45.82842712474619), 7: np.float64(7.0), 8: np.float64(66.24264068711928), 9: np.float64(18.0), 10: np.float64(30.82842712474619), 11: np.float64(226.56024609923625), 12: np.float64(14.414213562373096), 17: np.float64(28.0), 19: np.float64(21.414213562373096), 23: np.float64(16.99070478491457), 28: np.float64(10.0), 29: np.float64(32.071067811865476), 31: np.float64(16.0), 32: np.float64(16.0), 49: np.float64(10.0), 51: np.float64(12.0), 52: np.float64(15.242640687119287), 53: np.float64(51.071067811865476), 55: np.float64(9.16227766016838), 56: np.float64(6.0), 57: np.float64(3.0), 59: np.float64(14.0), 60: np.float64(5.414213562373095), 62: np.float64(0.0), 63: np.float64(12.0), 64: np.float64(6.0), 65: np.float64(14.414213562373096), 66: np.float64(15.0), 67: np.float64(13.82842712474619), 68: np.float64(14.0), 69: np.float64(2.0), 70: np.float64(8.0), 71: np.float64(9.0), 74: np.float64(17.414213562373096), 75: np.float64(15.99070478491457), 81: np.float64(22.886349517372675), 85: np.float64(6.0), 86: np.float64(134.26496277221963), 87: np.float64(6.0), 88: np.float64(12.23606797749979), 89: np.float64(4.0), 90: np.float64(3.0), 91: np.float64(8.0), 92: np.float64(5.414213562373095), 93: np.float64(5.0), 94: np.float64(2.0), 95: np.float64(16.51323307596588), 103: np.float64(4.0), 109: np.float64(0.0), 110: np.float64(3.0), 122: 0}

# %%
sorted_player_dist = dict(sorted(player_dist.items(), key=lambda item: item[1], reverse=True))
print(sorted_player_dist)
# Out:
# {1: np.float64(1540.472657794045), 2: np.float64(1018.820560213182), 11: np.float64(226.56024609923625), 86: np.float64(134.26496277221963), 8: np.float64(66.24264068711928), 53: np.float64(51.071067811865476), 6: np.float64(45.82842712474619), 5: np.float64(39.0), 29: np.float64(32.071067811865476), 10: np.float64(30.82842712474619), 17: np.float64(28.0), 81: np.float64(22.886349517372675), 19: np.float64(21.414213562373096), 9: np.float64(18.0), 74: np.float64(17.414213562373096), 4: np.float64(17.0), 23: np.float64(16.99070478491457), 95: np.float64(16.51323307596588), 31: np.float64(16.0), 32: np.float64(16.0), 75: np.float64(15.99070478491457), 52: np.float64(15.242640687119287), 66: np.float64(15.0), 12: np.float64(14.414213562373096), 65: np.float64(14.414213562373096), 59: np.float64(14.0), 68: np.float64(14.0), 67: np.float64(13.82842712474619), 88: np.float64(12.23606797749979), 51: np.float64(12.0), 63: np.float64(12.0), 28: np.float64(10.0), 49: np.float64(10.0), 55: np.float64(9.16227766016838), 71: np.float64(9.0), 70: np.float64(8.0), 91: np.float64(8.0), 3: np.float64(7.0), 7: np.float64(7.0), 56: np.float64(6.0), 64: np.float64(6.0), 85: np.float64(6.0), 87: np.float64(6.0), 60: np.float64(5.414213562373095), 92: np.float64(5.414213562373095), 93: np.float64(5.0), 89: np.float64(4.0), 103: np.float64(4.0), 57: np.float64(3.0), 90: np.float64(3.0), 110: np.float64(3.0), 69: np.float64(2.0), 94: np.float64(2.0), 62: np.float64(0.0), 109: np.float64(0.0), 122: 0}

# %%
actual_players = [list(sorted_player_dist.items())[0][0],
                  list(sorted_player_dist.items())[1][0]]
print(actual_players)
# Out:
# [1, 2]

# %%
tracking_updated = []

for frame in tracking:
  tr = []
  for player in frame:
    if int(player[2]) in actual_players: # player_id
      tr.append(player)
  tracking_updated.append(tr)

print(tracking_updated)
# Out:
# [[], [], [[566, 930, '1'], [1069, 308, '2']], [[578, 929, '1'], [1070, 308, '2']], [[588, 929, '1'], [1069, 307, '2']], [[599, 928, '1'], [1069, 307, '2']], [[616, 928, '1'], [1067, 306, '2']], [[629, 928, '1'], [1067, 305, '2']], [[650, 928, '1'], [1067, 310, '2']], [[663, 928, '1'], [1068, 316, '2']], [[674, 928, '1'], [1070, 318, '2']], [[678, 927, '1'], [1072, 319, '2']], [[682, 926, '1'], [1072, 319, '2']], [[685, 923, '1'], [1073, 320, '2']], [[697, 918, '1'], [1073, 320, '2']], [[711, 910, '1'], [1073, 319, '2']], [[719, 907, '1'], [1074, 318, '2']], [[732, 906, '1'], [1075, 315, '2']], [[749, 906, '1'], [1076, 310, '2']], [[761, 905, '1'], [1076, 308, '2']], [[772, 909, '1'], [1077, 308, '2']], [[783, 911, '1'], [1078, 308, '2']], [[788, 912, '1'], [1078, 308, '2']], [[799, 911, '1'], [1077, 307, '2']], [[811, 913, '1'], [1074, 308, '2']], [[820, 912, '1'], [1072, 307, '2']], [[831, 913, '1'], [1065, 306, '2']], [[844, 915, '1'], [1058, 305, '2']], [[852, 917, '1'], [1054, 309, '2']], [[859, 919, '1'], [1051, 311, '2']], [[863, 922, '1'], [1047, 311, '2']], [[864, 924, '1'], [1045, 311, '2']], [[
# %% [markdown]
# #### Tennis court: 78 feet long, 36 feet wide

# %%
xmin_proj, ymin_proj, xmax_proj, ymax_proj = 1482, 125, 1865, 956
# xmin_pitch, ymin_pitch, xmax_pitch, ymax_pitch = 581, 184, 1745,991
xmin_pitch, ymin_pitch, xmax_pitch, ymax_pitch = 645, 254, 1582, 845

width_proj = xmax_proj - xmin_proj
height_proj = ymax_proj - ymin_proj

radius = 7
color = (0, 0, 0)
thickness = 3

# Define the tennis court 2D lines

######### vertical lines
line_11 = (xmin_proj, ymin_proj)
line_12 = (xmin_proj, ymax_proj)

line_21 = (xmin_proj + int((4.5 / 36) * width_proj), ymin_proj)
line_22 = (xmin_proj + int((4.5 / 36) * width_proj), ymax_proj)

line_31 = (xmin_proj + int((18 / 36) * width_proj), ymin_proj + int((18 / 78) * height_proj))
line_32 = (xmin_proj + int((18 / 36) * width_proj), ymax_proj - int((18 / 78)  *height_proj))

line_41 = (xmin_proj + int((31.5 / 36) * width_proj), ymin_proj)
line_42 = (xmin_proj + int((31.5 / 36) * width_proj), ymax_proj)

line_51 = (xmin_proj + width_proj, ymin_proj)
line_52 = (xmin_proj + width_proj, ymax_proj)

######### horizontal lines
line_61 = (xmin_proj, ymin_proj)
line_62 = (xmax_proj, ymin_proj)

line_71 = (xmin_proj + int(( 4.5 / 36) * width_proj), ymin_proj + int((18 / 78) * height_proj))
line_72 = (xmin_proj + int((31.5 / 36) * width_proj), ymin_proj + int((18 / 78) * height_proj))

line_81 = (xmin_proj, ymin_proj + int((39 / 78) * height_proj))
line_82 = (xmax_proj, ymin_proj + int((39 / 78) * height_proj))

line_91 = (xmin_proj + int(( 4.5 / 36) * width_proj), ymax_proj - int((18 / 78) * height_proj))
line_92 = (xmin_proj + int((31.5 / 36) * width_proj), ymax_proj - int((18 / 78) * height_proj))

line_101 = (xmin_proj, ymax_proj)
line_102 = (xmax_proj, ymax_proj)

# Define line color and thickness
line_color = (255, 255, 255)
line_thickness = 2
alpha = 0.79  # Transparency factor

# %%
def draw_board (image, player_pos_1, player_pos_2, ball_pos):

  overlay = image.copy()
  lamda_x = 50
  lamda_y = 200
  cv2.rectangle(overlay, (xmin_proj - lamda_x, ymin_proj - lamda_y), (xmax_proj + lamda_x, ymax_proj + lamda_y), (0, 219, 0), -1)

  # Draw the court lines on the image
  cv2.line(overlay, line_11, line_12, line_color, line_thickness)
  cv2.line(overlay, line_21, line_22, line_color, line_thickness)
  cv2.line(overlay, line_31, line_32, line_color, line_thickness)
  cv2.line(overlay, line_41, line_42, line_color, line_thickness)
  cv2.line(overlay, line_51, line_52, line_color, line_thickness)
  cv2.line(overlay, line_61, line_62, line_color, line_thickness)
  cv2.line(overlay, line_71, line_72, line_color, line_thickness)
  cv2.line(overlay, line_81, line_82, line_color, line_thickness)
  cv2.line(overlay, line_91, line_92, line_color, line_thickness)
  cv2.line(overlay, line_101, line_102, line_color, line_thickness)

  # Players
  cv2.circle(overlay, (player_pos_1[0], player_pos_1[1]), radius, color, thickness)
  cv2.circle(overlay, (player_pos_2[0], player_pos_2[1]), radius, color, thickness)

  # Ball
  cv2.circle(overlay, (ball_pos[0], ball_pos[1]), radius - 5, line_color, thickness + 2)

  # Following line overlays transparent rectangle over the image
  image_new = cv2.addWeighted (overlay, alpha, image, 1 - alpha, 0)
  return image_new

# %%
# Homography

# %%
# pitch = [[xmin_pitch, ymin_pitch], [1391, ymin_pitch], [xmax_pitch, ymax_pitch], [198, 1008]]
# projs = [[xmin_proj, ymin_proj], [xmax_proj, ymin_proj], [xmax_proj, ymax_proj], [xmin_proj, ymax_proj]]

pitch = [[xmin_pitch, ymin_pitch], [1267, ymin_pitch], [xmax_pitch, ymax_pitch], [333, ymax_pitch]]
projs = [[xmin_proj, ymin_proj], [xmax_proj, ymin_proj], [xmax_proj, ymax_proj], [xmin_proj, ymax_proj]]

# %%
matrix, _ = cv2.findHomography (np.float32(pitch), np.float32(projs), method=0)

# %%
print(matrix)
# Out:
# [[     1.0864      5.0336      635.56]
#  [-5.0422e-16      5.3579     -1140.4]
#  [-6.3777e-19   0.0030094           1]]

# %%
def get_projections (matrix, kps):
  trans_kps = cv2.perspectiveTransform(np.float32([kps]).reshape(-1, 1, 2), matrix)
  return trans_kps[0][0].astype(int).tolist()

# %%
get_projections (matrix, [1266, 850])
# Out:
# [1767, 959]

# %%
input_video_path = "/content/drive/MyDrive/tennis-videos/tennis_video.mp4" ## CHANGE THIS
output_video_path = f"/content/drive/MyDrive/tennis-videos/output_video_s7h_{weights}.mp4"

video_cap = cv2.VideoCapture (input_video_path)

tracker = DeepSort(max_age=100) # track to identify the real players

frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(video_cap.get(cv2.CAP_PROP_FPS))

fourcc = cv2.VideoWriter_fourcc (*'mp4v')
writer = cv2.VideoWriter (output_video_path, fourcc, fps, (frame_width, frame_height))

# %%
tracking = []
k = 0

while video_cap.isOpened():

    start = datetime.datetime.now()
    ret, frame = video_cap.read()
    if not ret: break
    player_pos = []

    if len(tracking_updated[k]) > 0:

      for pl in tracking_updated[k]:
        xmin, ymin = pl[0], pl[1]
        cv2.rectangle(frame, (xmin, ymin), (xmin+2, ymin+2), (10, 255, 0), 2)
        cv2.putText(frame, "player_" + pl[2], (xmin, ymin-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
        player_pos.append([xmin, ymin])

      ball_pos = [0, 0]
      ball_bbox = ball_detections (frame) # Call the ball detection model

      if ball_bbox is not None:
        xmin_ball = int(ball_bbox[0])
        ymin_ball = int(ball_bbox[1])
        xmax_ball = int(ball_bbox[2])
        ymax_ball = int(ball_bbox[3])
        width = xmax_ball - xmin_ball
        height = ymax_ball - ymin_ball

        ball_pos = [xmin_ball + int(width/2), ymin_ball + int(height/2)]
        cv2.rectangle(frame, (xmin_ball, ymin_ball), (xmax_ball, ymax_ball), (255, 0, 0), 2)
        cv2.putText(frame, "ball", (xmin_ball, ymin_ball-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

      # Draw the 2D homograph
      frame = draw_board (
          frame,
          get_projections(matrix, player_pos[0]),
          get_projections(matrix, player_pos[1]),
          get_projections(matrix, ball_pos))

      writer.write(frame)
      end = datetime.datetime.now()
      print(f"Time to process 1 frame: {(end - start).total_seconds() * 1000:.0f} miliseconds")

    k += 1

video_cap.release()
writer.release()
# cv2.destroyAllWindows()
# Out:
# 0: 480x800 7 tennis balls, 79.0ms
# Speed: 7.5ms preprocess, 79.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 1446 miliseconds
#
# 0: 480x800 8 tennis balls, 51.8ms
# Speed: 5.0ms preprocess, 51.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 7 tennis balls, 53.0ms
# Speed: 4.7ms preprocess, 53.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 8 tennis balls, 52.7ms
# Speed: 4.4ms preprocess, 52.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 8 tennis balls, 51.3ms
# Speed: 4.8ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 9 tennis balls, 52.3ms
# Speed: 5.8ms preprocess, 52.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 8 tennis balls, 51.3ms
# Speed: 4.9ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 8 tennis balls, 51.7ms
# Speed: 5.0ms preprocess, 51.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 9 tennis balls, 52.0ms
# Speed: 5.7ms preprocess, 52.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 91 miliseconds
#
# 0: 480x800 8 tennis balls, 47.2ms
# Speed: 5.3ms preprocess, 47.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 79 miliseconds
#
# 0: 480x800 8 tennis balls, 47.1ms
# Speed: 4.8ms preprocess, 47.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 80 miliseconds
#
# 0: 480x800 9 tennis balls, 51.1ms
# Speed: 4.8ms preprocess, 51.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 81 miliseconds
#
# 0: 480x800 8 tennis balls, 53.3ms
# Speed: 3.6ms preprocess, 53.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 8 tennis balls, 50.2ms
# Speed: 4.8ms preprocess, 50.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 8 tennis balls, 52.1ms
# Speed: 4.0ms preprocess, 52.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 8 tennis balls, 52.1ms
# Speed: 5.2ms preprocess, 52.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 81 miliseconds
#
# 0: 480x800 9 tennis balls, 52.3ms
# Speed: 4.6ms preprocess, 52.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 9 tennis balls, 52.3ms
# Speed: 4.3ms preprocess, 52.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 9 tennis balls, 50.5ms
# Speed: 4.2ms preprocess, 50.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 80 miliseconds
#
# 0: 480x800 8 tennis balls, 48.7ms
# Speed: 5.0ms preprocess, 48.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 79 miliseconds
#
# 0: 480x800 8 tennis balls, 54.9ms
# Speed: 5.2ms preprocess, 54.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 8 tennis balls, 53.1ms
# Speed: 4.8ms preprocess, 53.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 52.7ms
# Speed: 4.4ms preprocess, 52.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 54.1ms
# Speed: 5.2ms preprocess, 54.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 8 tennis balls, 52.5ms
# Speed: 5.0ms preprocess, 52.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 9 tennis balls, 50.7ms
# Speed: 4.0ms preprocess, 50.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 81 miliseconds
#
# 0: 480x800 8 tennis balls, 52.0ms
# Speed: 5.6ms preprocess, 52.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 8 tennis balls, 51.8ms
# Speed: 4.8ms preprocess, 51.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 81 miliseconds
#
# 0: 480x800 6 tennis balls, 51.8ms
# Speed: 4.4ms preprocess, 51.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 4 tennis balls, 51.9ms
# Speed: 4.0ms preprocess, 51.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 5 tennis balls, 51.8ms
# Speed: 5.1ms preprocess, 51.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 5 tennis balls, 52.8ms
# Speed: 5.3ms preprocess, 52.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 53.1ms
# Speed: 3.7ms preprocess, 53.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 53.0ms
# Speed: 4.8ms preprocess, 53.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 51.7ms
# Speed: 4.4ms preprocess, 51.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 4 tennis balls, 52.0ms
# Speed: 5.3ms preprocess, 52.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 51.3ms
# Speed: 4.6ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 52.4ms
# Speed: 5.3ms preprocess, 52.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 53.3ms
# Speed: 4.7ms preprocess, 53.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 52.6ms
# Speed: 4.6ms preprocess, 52.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 5 tennis balls, 54.4ms
# Speed: 5.0ms preprocess, 54.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 52.1ms
# Speed: 4.9ms preprocess, 52.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 52.6ms
# Speed: 4.7ms preprocess, 52.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 6 tennis balls, 53.0ms
# Speed: 4.6ms preprocess, 53.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 52.6ms
# Speed: 4.7ms preprocess, 52.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 53.4ms
# Speed: 4.5ms preprocess, 53.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 90 miliseconds
#
# 0: 480x800 6 tennis balls, 49.7ms
# Speed: 4.7ms preprocess, 49.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 6 tennis balls, 53.1ms
# Speed: 4.7ms preprocess, 53.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 52.0ms
# Speed: 6.3ms preprocess, 52.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 91 miliseconds
#
# 0: 480x800 6 tennis balls, 50.5ms
# Speed: 5.1ms preprocess, 50.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 81 miliseconds
#
# 0: 480x800 7 tennis balls, 52.8ms
# Speed: 4.3ms preprocess, 52.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 51.8ms
# Speed: 4.7ms preprocess, 51.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 80 miliseconds
#
# 0: 480x800 6 tennis balls, 53.3ms
# Speed: 3.6ms preprocess, 53.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 52.7ms
# Speed: 4.5ms preprocess, 52.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 53.2ms
# Speed: 3.8ms preprocess, 53.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 53.3ms
# Speed: 5.0ms preprocess, 53.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 52.2ms
# Speed: 5.0ms preprocess, 52.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 52.5ms
# Speed: 5.3ms preprocess, 52.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 50.9ms
# Speed: 6.9ms preprocess, 50.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 53.3ms
# Speed: 5.2ms preprocess, 53.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 52.2ms
# Speed: 5.0ms preprocess, 52.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 49.9ms
# Speed: 8.4ms preprocess, 49.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 53.3ms
# Speed: 5.3ms preprocess, 53.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 52.7ms
# Speed: 6.6ms preprocess, 52.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 54.8ms
# Speed: 4.8ms preprocess, 54.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 53.3ms
# Speed: 4.9ms preprocess, 53.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 52.1ms
# Speed: 4.7ms preprocess, 52.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 52.7ms
# Speed: 5.3ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 6 tennis balls, 53.6ms
# Speed: 4.5ms preprocess, 53.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 6 tennis balls, 52.9ms
# Speed: 4.5ms preprocess, 52.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 82 miliseconds
#
# 0: 480x800 6 tennis balls, 53.0ms
# Speed: 5.6ms preprocess, 53.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 53.6ms
# Speed: 4.8ms preprocess, 53.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 52.0ms
# Speed: 5.9ms preprocess, 52.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 5 tennis balls, 51.4ms
# Speed: 7.4ms preprocess, 51.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 53.7ms
# Speed: 4.9ms preprocess, 53.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 52.6ms
# Speed: 7.4ms preprocess, 52.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 52.8ms
# Speed: 5.6ms preprocess, 52.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 97 miliseconds
#
# 0: 480x800 6 tennis balls, 50.7ms
# Speed: 5.7ms preprocess, 50.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 98 miliseconds
#
# 0: 480x800 6 tennis balls, 52.7ms
# Speed: 7.8ms preprocess, 52.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 95 miliseconds
#
# 0: 480x800 5 tennis balls, 51.3ms
# Speed: 9.1ms preprocess, 51.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 95 miliseconds
#
# 0: 480x800 5 tennis balls, 52.1ms
# Speed: 5.3ms preprocess, 52.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 90 miliseconds
#
# 0: 480x800 5 tennis balls, 52.7ms
# Speed: 8.4ms preprocess, 52.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 99 miliseconds
#
# 0: 480x800 5 tennis balls, 50.3ms
# Speed: 5.0ms preprocess, 50.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 98 miliseconds
#
# 0: 480x800 6 tennis balls, 49.0ms
# Speed: 4.8ms preprocess, 49.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 52.1ms
# Speed: 9.9ms preprocess, 52.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 103 miliseconds
#
# 0: 480x800 6 tennis balls, 49.7ms
# Speed: 4.9ms preprocess, 49.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 49.6ms
# Speed: 9.6ms preprocess, 49.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 95 miliseconds
#
# 0: 480x800 6 tennis balls, 52.3ms
# Speed: 4.8ms preprocess, 52.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 94 miliseconds
#
# 0: 480x800 6 tennis balls, 50.4ms
# Speed: 8.7ms preprocess, 50.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 99 miliseconds
#
# 0: 480x800 6 tennis balls, 51.5ms
# Speed: 5.6ms preprocess, 51.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 92 miliseconds
#
# 0: 480x800 6 tennis balls, 50.4ms
# Speed: 8.8ms preprocess, 50.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 93 miliseconds
#
# 0: 480x800 5 tennis balls, 52.9ms
# Speed: 4.8ms preprocess, 52.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 6 tennis balls, 50.7ms
# Speed: 9.2ms preprocess, 50.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 102 miliseconds
#
# 0: 480x800 8 tennis balls, 53.2ms
# Speed: 5.1ms preprocess, 53.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 100 miliseconds
#
# 0: 480x800 6 tennis balls, 49.1ms
# Speed: 9.1ms preprocess, 49.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 102 miliseconds
#
# 0: 480x800 6 tennis balls, 51.6ms
# Speed: 4.6ms preprocess, 51.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 7 tennis balls, 51.2ms
# Speed: 9.0ms preprocess, 51.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 105 miliseconds
#
# 0: 480x800 6 tennis balls, 51.5ms
# Speed: 6.7ms preprocess, 51.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 105 miliseconds
#
# 0: 480x800 7 tennis balls, 51.0ms
# Speed: 11.0ms preprocess, 51.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 101 miliseconds
#
# 0: 480x800 6 tennis balls, 50.4ms
# Speed: 10.2ms preprocess, 50.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 101 miliseconds
#
# 0: 480x800 6 tennis balls, 51.0ms
# Speed: 10.0ms preprocess, 51.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 98 miliseconds
#
# 0: 480x800 7 tennis balls, 50.2ms
# Speed: 5.1ms preprocess, 50.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 95 miliseconds
#
# 0: 480x800 7 tennis balls, 53.6ms
# Speed: 5.7ms preprocess, 53.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 92 miliseconds
#
# 0: 480x800 6 tennis balls, 51.9ms
# Speed: 6.5ms preprocess, 51.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 95 miliseconds
#
# 0: 480x800 5 tennis balls, 50.2ms
# Speed: 6.4ms preprocess, 50.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 94 miliseconds
#
# 0: 480x800 6 tennis balls, 53.1ms
# Speed: 6.8ms preprocess, 53.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 97 miliseconds
#
# 0: 480x800 7 tennis balls, 49.8ms
# Speed: 7.3ms preprocess, 49.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 91 miliseconds
#
# 0: 480x800 6 tennis balls, 51.0ms
# Speed: 6.9ms preprocess, 51.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 91 miliseconds
#
# 0: 480x800 6 tennis balls, 52.1ms
# Speed: 6.8ms preprocess, 52.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 107 miliseconds
#
# 0: 480x800 6 tennis balls, 48.0ms
# Speed: 7.7ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 97 miliseconds
#
# 0: 480x800 6 tennis balls, 48.6ms
# Speed: 10.2ms preprocess, 48.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 101 miliseconds
#
# 0: 480x800 7 tennis balls, 52.0ms
# Speed: 7.8ms preprocess, 52.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 101 miliseconds
#
# 0: 480x800 6 tennis balls, 51.4ms
# Speed: 11.8ms preprocess, 51.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 106 miliseconds
#
# 0: 480x800 7 tennis balls, 51.8ms
# Speed: 7.5ms preprocess, 51.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 95 miliseconds
#
# 0: 480x800 7 tennis balls, 51.9ms
# Speed: 7.9ms preprocess, 51.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 97 miliseconds
#
# 0: 480x800 7 tennis balls, 52.8ms
# Speed: 9.0ms preprocess, 52.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 104 miliseconds
#
# 0: 480x800 7 tennis balls, 46.8ms
# Speed: 9.9ms preprocess, 46.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 104 miliseconds
#
# 0: 480x800 7 tennis balls, 51.6ms
# Speed: 7.6ms preprocess, 51.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 100 miliseconds
#
# 0: 480x800 7 tennis balls, 50.6ms
# Speed: 7.1ms preprocess, 50.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 99 miliseconds
#
# 0: 480x800 6 tennis balls, 50.2ms
# Speed: 9.5ms preprocess, 50.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 103 miliseconds
#
# 0: 480x800 7 tennis balls, 47.5ms
# Speed: 8.6ms preprocess, 47.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 101 miliseconds
#
# 0: 480x800 7 tennis balls, 52.6ms
# Speed: 4.6ms preprocess, 52.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 53.0ms
# Speed: 5.4ms preprocess, 53.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 53.0ms
# Speed: 6.4ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 6 tennis balls, 52.7ms
# Speed: 4.6ms preprocess, 52.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 55.1ms
# Speed: 5.1ms preprocess, 55.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 52.1ms
# Speed: 6.4ms preprocess, 52.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 53.7ms
# Speed: 5.0ms preprocess, 53.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 52.4ms
# Speed: 5.0ms preprocess, 52.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 54.8ms
# Speed: 5.4ms preprocess, 54.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 54.2ms
# Speed: 5.2ms preprocess, 54.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 6 tennis balls, 52.3ms
# Speed: 5.4ms preprocess, 52.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 54.8ms
# Speed: 5.1ms preprocess, 54.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 92 miliseconds
#
# 0: 480x800 7 tennis balls, 51.7ms
# Speed: 6.0ms preprocess, 51.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 7 tennis balls, 52.7ms
# Speed: 4.9ms preprocess, 52.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 6 tennis balls, 55.1ms
# Speed: 4.6ms preprocess, 55.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 5 tennis balls, 53.2ms
# Speed: 4.5ms preprocess, 53.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 53.9ms
# Speed: 6.1ms preprocess, 53.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 52.7ms
# Speed: 6.4ms preprocess, 52.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 56.9ms
# Speed: 4.9ms preprocess, 56.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 5 tennis balls, 54.9ms
# Speed: 4.9ms preprocess, 54.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 53.2ms
# Speed: 5.8ms preprocess, 53.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 53.0ms
# Speed: 6.5ms preprocess, 53.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 53.5ms
# Speed: 6.4ms preprocess, 53.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 54.9ms
# Speed: 4.7ms preprocess, 54.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 91 miliseconds
#
# 0: 480x800 6 tennis balls, 51.3ms
# Speed: 7.5ms preprocess, 51.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 7 tennis balls, 54.2ms
# Speed: 4.8ms preprocess, 54.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 7 tennis balls, 51.6ms
# Speed: 5.9ms preprocess, 51.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 7 tennis balls, 53.1ms
# Speed: 7.7ms preprocess, 53.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 6 tennis balls, 53.2ms
# Speed: 6.2ms preprocess, 53.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 55.5ms
# Speed: 4.9ms preprocess, 55.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 54.0ms
# Speed: 4.7ms preprocess, 54.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 52.6ms
# Speed: 7.2ms preprocess, 52.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 7 tennis balls, 53.0ms
# Speed: 5.1ms preprocess, 53.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 55.3ms
# Speed: 6.1ms preprocess, 55.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 7 tennis balls, 50.7ms
# Speed: 8.3ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 55.3ms
# Speed: 5.0ms preprocess, 55.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 93 miliseconds
#
# 0: 480x800 6 tennis balls, 52.5ms
# Speed: 5.5ms preprocess, 52.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 6 tennis balls, 50.8ms
# Speed: 6.2ms preprocess, 50.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 54.2ms
# Speed: 4.6ms preprocess, 54.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 54.3ms
# Speed: 7.0ms preprocess, 54.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 6 tennis balls, 53.2ms
# Speed: 6.3ms preprocess, 53.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 53.0ms
# Speed: 5.4ms preprocess, 53.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 5 tennis balls, 53.8ms
# Speed: 6.7ms preprocess, 53.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 5 tennis balls, 53.5ms
# Speed: 4.9ms preprocess, 53.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 54.8ms
# Speed: 5.0ms preprocess, 54.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 53.3ms
# Speed: 6.0ms preprocess, 53.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 5 tennis balls, 52.5ms
# Speed: 6.4ms preprocess, 52.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 55.0ms
# Speed: 5.2ms preprocess, 55.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 93 miliseconds
#
# 0: 480x800 6 tennis balls, 49.8ms
# Speed: 6.3ms preprocess, 49.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 52.3ms
# Speed: 4.8ms preprocess, 52.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 7 tennis balls, 54.6ms
# Speed: 6.6ms preprocess, 54.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 7 tennis balls, 54.0ms
# Speed: 4.0ms preprocess, 54.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 7 tennis balls, 53.6ms
# Speed: 5.4ms preprocess, 53.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 7 tennis balls, 54.2ms
# Speed: 5.1ms preprocess, 54.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 8 tennis balls, 54.8ms
# Speed: 7.7ms preprocess, 54.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 7 tennis balls, 53.3ms
# Speed: 4.9ms preprocess, 53.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 7 tennis balls, 53.8ms
# Speed: 4.8ms preprocess, 53.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 54.5ms
# Speed: 5.2ms preprocess, 54.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 54.4ms
# Speed: 4.8ms preprocess, 54.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 54.7ms
# Speed: 5.0ms preprocess, 54.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 92 miliseconds
#
# 0: 480x800 9 tennis balls, 50.4ms
# Speed: 6.2ms preprocess, 50.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 6 tennis balls, 53.5ms
# Speed: 4.8ms preprocess, 53.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 7 tennis balls, 52.9ms
# Speed: 7.4ms preprocess, 52.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 52.2ms
# Speed: 7.6ms preprocess, 52.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 54.0ms
# Speed: 6.3ms preprocess, 54.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 53.8ms
# Speed: 5.3ms preprocess, 53.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 53.9ms
# Speed: 6.5ms preprocess, 53.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 53.7ms
# Speed: 4.9ms preprocess, 53.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 53.6ms
# Speed: 5.0ms preprocess, 53.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 53.6ms
# Speed: 5.2ms preprocess, 53.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 53.8ms
# Speed: 4.6ms preprocess, 53.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 55.2ms
# Speed: 5.0ms preprocess, 55.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 91 miliseconds
#
# 0: 480x800 6 tennis balls, 52.1ms
# Speed: 6.6ms preprocess, 52.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 6 tennis balls, 53.6ms
# Speed: 5.0ms preprocess, 53.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 6 tennis balls, 54.9ms
# Speed: 7.3ms preprocess, 54.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 87 miliseconds
#
# 0: 480x800 5 tennis balls, 54.3ms
# Speed: 5.7ms preprocess, 54.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 53.8ms
# Speed: 5.9ms preprocess, 53.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 53.5ms
# Speed: 5.0ms preprocess, 53.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 4 tennis balls, 53.8ms
# Speed: 5.5ms preprocess, 53.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 54.7ms
# Speed: 6.7ms preprocess, 54.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 5 tennis balls, 54.0ms
# Speed: 5.2ms preprocess, 54.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 88 miliseconds
#
# 0: 480x800 5 tennis balls, 52.3ms
# Speed: 5.0ms preprocess, 52.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 6 tennis balls, 52.5ms
# Speed: 7.1ms preprocess, 52.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 4 tennis balls, 52.8ms
# Speed: 7.1ms preprocess, 52.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 94 miliseconds
#
# 0: 480x800 5 tennis balls, 50.8ms
# Speed: 5.5ms preprocess, 50.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 54.0ms
# Speed: 4.7ms preprocess, 54.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 86 miliseconds
#
# 0: 480x800 6 tennis balls, 54.4ms
# Speed: 4.7ms preprocess, 54.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 85 miliseconds
#
# 0: 480x800 5 tennis balls, 54.0ms
# Speed: 6.4ms preprocess, 54.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 89 miliseconds
#
# 0: 480x800 4 tennis balls, 51.8ms
# Speed: 5.4ms preprocess, 51.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 84 miliseconds
#
# 0: 480x800 5 tennis balls, 54.1ms
# Speed: 4.9ms preprocess, 54.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
#
# 0: 480x800 5 tennis balls, 54.0ms
# Speed: 4.2ms preprocess, 54.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
# Time to process 1 frame: 83 miliseconds
